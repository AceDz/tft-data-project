# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent 

sys.path.append(str(PROJECT_ROOT))

print("PROJECT ROOT:", PROJECT_ROOT)
print("SRC EXISTS:", (PROJECT_ROOT / "src").exists())
# Out:
# PROJECT ROOT: c:\Users\acepu\Documents\tft-data-project
# SRC EXISTS: True

# %%
from src.extract import get_puuid, get_match_ids, get_match_data
import src.storage as storage

game_name = "AceÐz"
tag_line = "EUW"

puuid = get_puuid(game_name, tag_line)
matches = get_match_ids(puuid)

for match_id in matches:
    match_data = get_match_data(match_id)
    
    if match_data is None:
        continue
    path = storage.save_raw_match(match_id, match_data)
    
    print("Saved:", path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      11     match_data = get_match_data(match_id)
#      12
#      13     if match_data is None:
#      14         continue
# ---> 15     path = storage.save_match_data(match_id, match_data)
#      16
#      17     print("Saved:", path)
#
# AttributeError: module 'src.storage' has no attribute 'save_match_data'
