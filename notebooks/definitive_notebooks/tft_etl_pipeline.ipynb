# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent 

sys.path.append(str(PROJECT_ROOT))

print("PROJECT ROOT:", PROJECT_ROOT)
print("SRC EXISTS:", (PROJECT_ROOT / "src").exists())
# Out:
# PROJECT ROOT: c:\Users\acepu\Documents\tft-data-project
# SRC EXISTS: True

# %%
from dotenv import load_dotenv
from src.extract import get_puuid, get_match_ids, get_match_data
import src.storage as storage
from src.normalize import normalize_match
import src.validate as validate
import src.load as load
import pandas as pd
from sqlalchemy import create_engine
import os

"""game_name = "AceÐz"
tag_line = "EUW"

load_dotenv()
puuid = get_puuid(game_name, tag_line)
matches = get_match_ids(puuid)

for match_id in matches:
    match_data = get_match_data(match_id)
    
    if match_data is None:
        continue
    path = storage.save_raw_match(match_id, match_data)
    
    print("Saved:", path)
    


fact_matches, fact_traits, fact_units = (normalize_match(match_data))



validate.validate_all(
    fact_matches,
    fact_traits,
    fact_units
)

load.load_to_postgres(
    fact_matches,
    fact_traits,
    fact_units
)"""

load_dotenv()

DB_HOST = os.getenv("POSTGRES_HOST")
DB_PORT = os.getenv("POSTGRES_PORT")
DB_NAME = os.getenv("POSTGRES_DB")
DB_USER = os.getenv("POSTGRES_USER")
DB_PASSWORD = os.getenv("POSTGRES_PASSWORD")


engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

pd.read_sql("SELECT * FROM fact_matches f JOIN dim_match_player dmp ORDER BY placement", engine)
# Out:
#           match_id                                       data_version  \
# 0  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 1  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 2  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 3  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 4  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 5  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 6  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
# 7  EUW1_7855663168  Linux Version 16.10.776.5552 (May 13 2026/16:2...
#
#                                                puuid  placement  level  \
# 0  SbjmF6BU_GHq_dxmuBdYpcPzNO4_wMJfsWtBzt55Cv6ebW...          1     10
# 1  6NJNXjfeQi8Hb42Zi-STb_p9d6RFfEyyJ59tkfymT0UixF...          2     10
# 2  YJB78VgyNdmhUPnBqHyXdxNhd7miaHLrBKymlbpHh0_HEp...          3     10
# ...
